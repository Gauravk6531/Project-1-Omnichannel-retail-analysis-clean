# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sales = pd.read_csv(r"C:\Users\ASUS\Desktop\Desktop\Infotact Internship\Project 1 clean\Project-1-Omnichannel-retail-analysis-clean\cleaned_data\retail_sales_cleaned.csv")
df_inv = pd.read_csv(r"C:\Users\ASUS\Desktop\Desktop\Infotact Internship\Project 1 clean\Project-1-Omnichannel-retail-analysis-clean\cleaned_data\retail_inventory_cleaned.csv")

# %%
# Out:
#        transaction_date  sales_type  is_return     supplier   product_no  \
# 0            2025-09-01  Full Price          0  Vendor 0169  PROD-139867
# 1            2025-09-07  Full Price          0  Vendor 0166  PROD-100449
# 2            2025-08-06       Promo          0  Vendor 0169  PROD-153623
# 3            2025-08-31  Full Price          0  Vendor 0246  PROD-140876
# 4            2026-03-22  Full Price          0  Vendor 0169  PROD-166113
# ...                 ...         ...        ...          ...          ...
# 125746       2025-12-12  Full Price          0  Vendor 0169  PROD-165949
# 125747       2025-10-18  Full Price          0  Vendor 0064  PROD-112072
# 125748       2025-10-06  Full Price          0  Vendor 0064  PROD-125404
# 125749       2025-10-18  Full Price          0  Vendor 0166  PROD-103739
# 125750       2025-07-16  Full Price          1  Vendor 0169  PROD-165957
#
#                                       product_description  product_division  \
# 0       PROD-100449 SEG-500065 Scholar Footwear Trailb...  Scholar Footwear
# 1       PROD-100825 SEG-500112 Heritage Footwear Fligh...    Femme Footwear
# 2       PROD-148813 SEG-511388 Scholar Footwear Trailb...  Scholar Footwear
# 3       PROD-100419 SEG-500063 Scholar Footwear Boot C...  Scholar Footwear
# 4       PROD-149345 SEG-511444 Femme Footwear Trailbla...    Femme Footwear
# ...                                                   ...               ...
# 125746  PROD-148742 SEG-511381 Scholar Footwear Trailb...  Scholar Footwear
# 125747  PROD-103307 SEG-500452 Scholar Footwear Boot C...  Scholar Footwear
# 125748  PROD-185210 SEG-519441 Femme Footwear Boot Col...    Femme Footwear
# 125749  PROD-152512 SEG-512312 Scholar Footwear Court ...  Scholar Footwear
# 125750  PROD-102502 SEG-500344 Scholar Footwear Trailb...  Scholar Footwear
#
#                         product_category  \
# 0           Scholar Footwear Trailblazer
# 1          Femme Footwear Flight Classic
# 2           Scholar Footwear Trailblazer
# 3       Scholar Footwear Boot Collection
# 4             Femme Footwear Trailblazer
# ...                                  ...
# 125746      Scholar Footwear Trailblazer
# 125747  Scholar Footwear Boot Collection
# 125748    Femme Footwear Boot Collection
# 125749     Scholar Footwear Court Casual
# 125750      Scholar Footwear Trailblazer
#
#                                product_subcategory  \
# 0         Scholar Footwear Trailblazer Equilibrium
# 1             Femme Footwear Flight Classic Varied
# 2         Scholar Footwear Trailblazer Equilibrium
# 3        Scholar Footwear Boot Collection Woodland
# 4           Femme Footwear Trailblazer Equilibrium
# ...                                            ...
# 125746    Scholar Footwear Trailblazer Equilibrium
# 125747  Scholar Footwear Boot Collection Plushfoot
# 125748    Femme Footwear Boot Collection Plushfoot
# 125749        Scholar Footwear Court Casual Zephyr
# 125750    Scholar Footwear Trailblazer Equilibrium
#
#                                           product_segment     store  \
# 0       SEG-500065 Scholar Footwear Trailblazer Equili...  STR-1006
# 1       SEG-500112 Heritage Footwear Flight Classic Ze...  STR-1198
# 2       SEG-511388 Scholar Footwear Trailblazer Equili...  STR-1157
# 3       SEG-500063 Scholar Footwear Boot Collection Wo...  STR-1234
# 4       SEG-511444 Femme Footwear Trailblazer Equilibrium  STR-1157
# ...                                                   ...       ...
# 125746  SEG-511381 Scholar Footwear Trailblazer Equili...  STR-1335
# 125747  SEG-500452 Scholar Footwear Boot Collection Pl...  STR-1335
# 125748  SEG-519441 Femme Footwear Boot Collection Plus...  STR-1350
# 125749    SEG-512312 Scholar Footwear Court Casual Zephyr  STR-1234
# 125750  SEG-500344 Scholar Footwear Trailblazer Equili...  STR-1369
#
#         sales_channel  qty_sold  sales_amount   cogs  number_of_transactions
# 0       Channel Alpha         1        115.00  52.31                       1
# 1       Channel Alpha         1        115.00  58.47                       1
# 2       Channel Alpha         1         79.99  43.76                       1
# 3       Channel Alpha         1        110.00  50.60                       1
# 4       Channel Alpha         1        160.00  77.95                       1
# ...               ...       ...           ...    ...                     ...
# 125746  Channel Alpha         1        110.00  50.05                       1
# 125747  Channel Alpha         1         59.50  38.68                       1
# 125748  Channel Alpha         1        125.00  51.70                       1
# 125749  Channel Alpha         1         92.00  46.55                       1
# 125750  Channel Alpha        -1        -85.00 -38.68                       1
#
# [125751 rows x 16 columns]
