# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_inventory = pd.read_csv(r"C:\Users\ASUS\Desktop\Desktop\Infotact Internship\Project 1 clean\Project-1-Omnichannel-retail-analysis-clean\data\retail_inventory_ml_apl.csv")

# %%
print(df_inventory.info())
print(df_inventory.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284755 entries, 0 to 284754
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Start Date                284755 non-null  str
#  1   End Date                  284755 non-null  str
#  2   Stock Status              284755 non-null  str
#  3   Supplier                  284755 non-null  str
#  4   Product No                284755 non-null  str
#  5   Product Description       284755 non-null  str
#  6   Product Division          284755 non-null  str
#  7   Product Category          284755 non-null  str
#  8   Product Subcategory       284755 non-null  str
#  9   Product Segment           284755 non-null  str
#  10  Store                     284755 non-null  str
#  11  Store Type                284755 non-null  str
#  12  Sales Channel             284755 non-null  str
#  13  Qty on hand               284755 non-null  int64
# ...

# %%
df_inventory.isna().sum()
# Out:
# Start Date                  0
# End Date                    0
# Stock Status                0
# Supplier                    0
# Product No                  0
# Product Description         0
# Product Division            0
# Product Category            0
# Product Subcategory         0
# Product Segment             0
# Store                       0
# Store Type                  0
# Sales Channel               0
# Qty on hand                 0
# Stocks Selling Amount       0
# Cost of Stocks              0
# Stock Unit Selling Price    0
# Stock Unit Cost Price       0
# dtype: int64

# %%
print("Standardizing column schemas to snake_case...")
# Strip whitespace, lower case, replace spaces with underscores
df_inventory.columns = df_inventory.columns.str.strip().str.lower().str.replace(' ', '_')
# Out:
# Standardizing column schemas to snake_case...

# %%
print("Reformatting date boundaries...")
df_inventory['start_date'] = pd.to_datetime(df_inventory['start_date'])
df_inventory['end_date'] = pd.to_datetime(df_inventory['end_date'])
# Out:
# Reformatting date boundaries...

# %%
df_inventory.to_csv(r'C:\Users\ASUS\Desktop\Desktop\Infotact Internship\Project 1 clean\Project-1-Omnichannel-retail-analysis-clean\cleaned_data\retail_inventory_cleaned.csv', index=False)

# %%
df_inventory.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284755 entries, 0 to 284754
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   start_date                284755 non-null  datetime64[us]
#  1   end_date                  284755 non-null  datetime64[us]
#  2   stock_status              284755 non-null  str
#  3   supplier                  284755 non-null  str
#  4   product_no                284755 non-null  str
#  5   product_description       284755 non-null  str
#  6   product_division          284755 non-null  str
#  7   product_category          284755 non-null  str
#  8   product_subcategory       284755 non-null  str
#  9   product_segment           284755 non-null  str
#  10  store                     284755 non-null  str
#  11  store_type                284755 non-null  str
#  12  sales_channel             284755 non-null  str
#  13  qty_on_hand               284755 non-null  int64
# ...
